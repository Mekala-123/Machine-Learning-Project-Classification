# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Concrete Compressive Strength.csv")
df
# Out:
#       Cement  Blast_Furnance_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                  0.0      0.0  162.0               2.5
# 1      540.0                  0.0      0.0  162.0               2.5
# 2      332.5                142.5      0.0  228.0               0.0
# 3      332.5                142.5      0.0  228.0               0.0
# 4      198.6                132.4      0.0  192.0               0.0
# ...      ...                  ...      ...    ...               ...
# 1025   276.4                116.0     90.3  179.6               8.9
# 1026   322.2                  0.0    115.6  196.0              10.4
# 1027   148.5                139.4    108.6  192.7               6.1
# 1028   159.1                186.7      0.0  175.6              11.3
# 1029   260.9                100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age_Day  Concrete_Strength
# 0               1040.0           676.0       28          79.986111
# ...

# %% [markdown]
# Column Name	Likely Unit	Description
# Cement	kg/m³	Amount of cement per cubic meter of concrete
# Blast_Furnace_Slag	kg/m³	Amount of blast furnace slag per cubic meter
# Fly_Ash	kg/m³	Amount of fly ash per cubic meter
# Water	kg/m³	Water content per cubic meter (1 kg ≈ 1 liter)
# Superplasticizer	kg/m³	Additive (chemical) per cubic meter
# Coarse_Aggregate	kg/m³	Gravel or crushed stone per cubic meter
# Fine_Aggregate	kg/m³	Sand per cubic meter
# Age_Day	days	Age of the concrete when strength is measured
# Concrete_Strength	MPa (Megapascals)	Compressive strength of concrete

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cement               1030 non-null   float64
#  1   Blast_Furnance_Slag  1030 non-null   float64
#  2   Fly_Ash              1030 non-null   float64
#  3   Water                1030 non-null   float64
#  4   Superplasticizer     1030 non-null   float64
#  5   Coarse_Aggregate     1030 non-null   float64
#  6   Fine_Aggregate       1030 non-null   float64
#  7   Age_Day              1030 non-null   int64
#  8   Concrete_Strength    1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
df.head()
# Out:
#    Cement  Blast_Furnance_Slag  Fly_Ash  Water  Superplasticizer  \
# 0   540.0                  0.0      0.0  162.0               2.5
# 1   540.0                  0.0      0.0  162.0               2.5
# 2   332.5                142.5      0.0  228.0               0.0
# 3   332.5                142.5      0.0  228.0               0.0
# 4   198.6                132.4      0.0  192.0               0.0
#
#    Coarse_Aggregate  Fine_Aggregate  Age_Day  Concrete_Strength
# 0            1040.0           676.0       28          79.986111
# 1            1055.0           676.0       28          61.887366
# 2             932.0           594.0      270          40.269535
# 3             932.0           594.0      365          41.052780
# 4             978.4           825.5      360          44.296075

# %%
df.describe()
# Out:
#             Cement  Blast_Furnance_Slag      Fly_Ash        Water  \
# count  1030.000000          1030.000000  1030.000000  1030.000000
# mean    281.165631            73.895485    54.187136   181.566359
# std     104.507142            86.279104    63.996469    21.355567
# min     102.000000             0.000000     0.000000   121.750000
# 25%     192.375000             0.000000     0.000000   164.900000
# 50%     272.900000            22.000000     0.000000   185.000000
# 75%     350.000000           142.950000   118.270000   192.000000
# max     540.000000           359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse_Aggregate  Fine_Aggregate      Age_Day  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.203112        972.918592      773.578883    45.662136
# std            5.973492         77.753818       80.175427    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %% [markdown]
# # NULL VALUES HANDLING

# %%
df.isnull().sum()
# Out:
# Cement                 0
# Blast_Furnance_Slag    0
# Fly_Ash                0
# Water                  0
# Superplasticizer       0
# Coarse_Aggregate       0
# Fine_Aggregate         0
# Age_Day                0
# Concrete_Strength      0
# dtype: int64

# %% [markdown]
# # OUTLIERS HANDLING

# %%
#sns.boxplot(x="Area",data=df)

columns_to_plot = ['Cement','Blast_Furnance_Slag','Fly_Ash','Water','Superplasticizer',
                   'Coarse_Aggregate','Fine_Aggregate','Age_Day','Concrete_Strength']

rows = 3  # 3 rows
cols = 3  # 3 columns → 3 x 3 = 9 plots

fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

axes = axes.flatten()  # Flatten to a 1D list for easy indexing

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column}')

plt.tight_layout()
plt.show()

# %%
columns = ['Blast_Furnance_Slag','Water','Superplasticizer',
                   'Fine_Aggregate','Age_Day','Concrete_Strength']
n = len(columns)

# Set up subplots (adjust rows/cols as needed)
rows = (n + 1) // 2  # 2 plots per row
fig, axes = plt.subplots(rows, 2, figsize=(12, 4 * rows))

# Flatten axes to handle both 1D and 2D
axes = axes.flatten()

# Plot each histogram
for i, col in enumerate(columns):
    sns.histplot(df[col], kde=True, ax=axes[i])
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel(col)

# Hide any unused subplots (if number of columns is odd)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
#IQR- winsorization-Replacing the the values with most permissble values i..ee  lower and upper bounds

def replace_outliers(dataframe,feature):
    Q1=dataframe[feature].quantile(0.25)
    Q3=dataframe[feature].quantile(0.75)

    IQR=Q3-Q1

    upper_bound=Q3+1.5*IQR  
    lower_bound=Q1-1.5*IQR

    # capping-replacing all higher values with upper bound (75% percentile)
    dataframe[feature]=np.where(dataframe[feature]>upper_bound,upper_bound,dataframe[feature])
    # flooring -replace all lower values with lower bounf (25% percentile)
    dataframe[feature]=np.where(dataframe[feature]<lower_bound,lower_bound,dataframe[feature])

for col in ['Blast_Furnance_Slag','Water','Superplasticizer','Fine_Aggregate','Age_Day','Concrete_Strength']:
    replace_outliers(df, col)

# %%
#sns.boxplot(x="Area",data=df)

columns_to_plot = ['Blast_Furnance_Slag','Water','Superplasticizer','Fine_Aggregate','Age_Day','Concrete_Strength']

rows = 2  # 3 rows
cols = 3  # 3 columns → 2 x 3 = 6 plots

fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

axes = axes.flatten()  # Flatten to a 1D list for easy indexing

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %%
corr2=df.corr()
corr2
# Out:
#                        Cement  Blast_Furnance_Slag   Fly_Ash     Water  \
# Cement               1.000000            -0.275217 -0.397475 -0.081588
# Blast_Furnance_Slag -0.275217             1.000000 -0.323580  0.107064
# Fly_Ash             -0.397475            -0.323580  1.000000 -0.258428
# Water               -0.081588             0.107064 -0.258428  1.000000
# Superplasticizer     0.079708             0.043887  0.395515 -0.665254
# Coarse_Aggregate    -0.109356            -0.284023 -0.009977 -0.180260
# Fine_Aggregate      -0.225313            -0.283254  0.080930 -0.448966
# Age_Day              0.054323            -0.052704 -0.092705  0.189629
# Concrete_Strength    0.498009             0.134617 -0.105576 -0.290966
#
#                      Superplasticizer  Coarse_Aggregate  Fine_Aggregate  \
# Cement                       0.079708         -0.109356       -0.225313
# Blast_Furnance_Slag          0.043887         -0.284023       -0.283254
# ...

# %%
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr2, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Selected Features")
plt.show()

# %% [markdown]
# NO ENCODING

# %%
x=df.iloc[:, :-1] #All columns except the last (Except Target)

y=df.iloc[:, -1] #The last column (Target)

# %%
x
# Out:
#       Cement  Blast_Furnance_Slag  Fly_Ash  Water  Superplasticizer  \
# 0      540.0                  0.0      0.0  162.0               2.5
# 1      540.0                  0.0      0.0  162.0               2.5
# 2      332.5                142.5      0.0  228.0               0.0
# 3      332.5                142.5      0.0  228.0               0.0
# 4      198.6                132.4      0.0  192.0               0.0
# ...      ...                  ...      ...    ...               ...
# 1025   276.4                116.0     90.3  179.6               8.9
# 1026   322.2                  0.0    115.6  196.0              10.4
# 1027   148.5                139.4    108.6  192.7               6.1
# 1028   159.1                186.7      0.0  175.6              11.3
# 1029   260.9                100.5     78.3  200.6               8.6
#
#       Coarse_Aggregate  Fine_Aggregate  Age_Day
# 0               1040.0           676.0     28.0
# 1               1055.0           676.0     28.0
# ...

# %%
y
# Out:
# 0       79.780044
# 1       61.887366
# 2       40.269535
# 3       41.052780
# 4       44.296075
#           ...
# 1025    44.284354
# 1026    31.178794
# 1027    23.696601
# 1028    32.768036
# 1029    32.401235
# Name: Concrete_Strength, Length: 1030, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42) #test _size=0.2-split 80 and 20 ..,random_state=42=>

# %% [markdown]
# # SCALING

# %%
#scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

x_train_scaled=scaler.fit_transform(x_train)
x_train_scaled

x_test_scaled=scaler.transform(x_test)

# %% [markdown]
# # LinearRegression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test_scaled)

# %%
#testing accuracy
from sklearn.metrics import r2_score    #r2_score for accurasy find,metrics->less accuracy valu it will take
r2_score(y_test,y_pred)*100
# Out:
# 74.59334448168664

# %%
#training accuracy

y2_pred=model.predict(x_train_scaled)
print ("Accuracy is "), r2_score(y_train,y2_pred)*100
# Out:
# Accuracy is
# (None, 72.4037524275823)

# %%
# Lasso Regression (L1 Regularization)
lasso = Lasso(alpha=0.1)  # Try different alphas like 0.01, 0.1, 1
lasso.fit(x_train, y_train)
y_pred_lasso = lasso.predict(x_test)
print("Lasso Regression R2 :", r2_score(y_test, y_pred_lasso)*100)
# Out:
# Lasso Regression R2 : 74.58372401591306

# %%
# Ridge Regression (L2 Regularization)
ridge = Ridge(alpha=1)  # Try different alphas like 0.1, 1, 10
ridge.fit(x_train, y_train)
y_pred_ridge = ridge.predict(x_test)
print("Ridge Regression R2 :", r2_score(y_test, y_pred_ridge)*100)
# Out:
# Ridge Regression R2 : 74.59331983385901

# %% [markdown]
# TUNNING Method

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Lasso, ElasticNet

# Parameter grid
param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100]  # Regularization strength
}
ridge = Ridge()
lasso = Lasso()
elastic = ElasticNet()

# Grid Search with cross-validation
grid_search = GridSearchCV(ridge, param_grid, cv=5, scoring='r2')
grid_search.fit(x_train_scaled, y_train)

best_ridge = grid_search.best_estimator_
print("Best alpha:", grid_search.best_params_['alpha'])
# Out:
# Best alpha: 1

# %% [markdown]
# # SVM Model

# %%
from sklearn.svm import SVR  # support vector classification =because we using classification
model=SVR(kernel="rbf",C=100,gamma="auto", epsilon = 0.5,) #Rgularization-> parameters=kernel,c(kernel,c=10 r 1)
model
# Out:
# SVR(C=100, epsilon=0.5, gamma='auto')

# %%
final=model.fit(x_train_scaled,y_train)
final
# Out:
# SVR(C=100, epsilon=0.5, gamma='auto')

# %%
#testing accuracy

y_pred=model.predict(x_test_scaled)
accuracy=r2_score(y_test,y_pred)
print(f"Accuracy: {accuracy * 100 :2f}%")
# Out:
# Accuracy: 87.834730%

# %%
#training accuracy

y2_pred=model.predict(x_train_scaled)
print ("Accuracy is "), r2_score(y_train,y2_pred)*100
# Out:
# Accuracy is
# (None, 95.03354283468836)

# %%
#hyperparameter tunning(beore testing we can find accuracy which is the best)-cross validation(CV)
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10,100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'epsilon': [0.1, 0.2, 0.5]
}

grid_search = GridSearchCV(SVR(), param_grid, cv=5)

grid_search.fit(x_train_scaled, y_train)

print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'C': 100, 'epsilon': 0.5, 'gamma': 'auto', 'kernel': 'rbf'}

# %% [markdown]
# # KNN

# %%
#To find K
import math
math.sqrt(len(y_test))
# Out:
# 14.352700094407323

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=5, metric = 'euclidean',weights = 'distance')

# %%
model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsRegressor(metric='euclidean', weights='distance')

# %%
y_pred=model.predict(x_test_scaled)
print(r2_score(y_test,y_pred)*100)
# Out:
# 82.06861592042358

# %%
y2_pred=model.predict(x_train_scaled)
print(r2_score(y_train,y2_pred)*100)
# Out:
# 99.72211746761961

# %%
#hyperparameter tunning(beore testing we can find accuracy which is the best)-cross validation(CV)

from sklearn.model_selection import GridSearchCV
param_grid= {
    'n_neighbors':[3,5,7,9,11],
    'metric':['euclidean','manhatten'],
    'weights': ['uniform', 'distance'],
}

grid_search = GridSearchCV(KNeighborsRegressor(), param_grid, cv=5)

grid_search.fit(x_train_scaled, y_train)

print(grid_search.best_params_)
# Out:
# {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=42,criterion='squared_error', max_depth = 20, min_samples_leaf= 1, min_samples_split= 13)
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_split=13, random_state=42)

# %%
y_pred=model.predict(x_test)
print(r2_score(y_test,y_pred)*100)
# Out:
# 80.91814649215972

# %%
y2_pred=model.predict(x_train)
print(r2_score(y_train,y2_pred)*100)
# Out:
# 95.46286347218698

# %%
# No gini,entropy for regression model

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define parameter distributions for Randomized Search
param_dist = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'], # valid for regression
    'max_depth': [None, 5, 10, 20, 30],
    'min_samples_split': randint(2,5, 11),
    'min_samples_leaf': randint(1,2, 5),
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_distributions=param_dist,
    n_iter=10,  # You can increase this for more exploration
    cv=5,
    random_state=42
)

# Fit on training data
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best parameters:", random_search.best_params_)
# Out:
# Best parameters: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 13}

# %% [markdown]
# BOOSTING

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score


base_estimator = DecisionTreeRegressor(max_depth=4)

# Initialize AdaBoost Regressor
ada_reg = AdaBoostRegressor(estimator=base_estimator,n_estimators=100,learning_rate=0.1,random_state=42)


ada_reg.fit(x_train, y_train)


y_pred = ada_reg.predict(x_test)


mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)*100

print(f"Mean Squared Error: {mse:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Squared Error: 59.0360
# R² Score: 77.0895

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=240 ,max_depth = None, max_features = 'sqrt', min_samples_leaf = 1, min_samples_split= 9,)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', min_samples_split=9,
#                       n_estimators=240)

# %%
accuracy = rf_model.score(x_test, y_test)*100
print("Model Accurcy:",accuracy)
# Out:
# Model Accurcy: 85.84473515740503

# %%
accuracy1 = rf_model.score(x_train, y_train)*100
print("Model Accurcy:",accuracy1)
# Out:
# Model Accurcy: 94.52772603126846

# %% [markdown]
# Hyperparameter Tunning

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint


param_dist = {'n_estimators': randint(50,500),
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': randint(2, 10),
            'min_samples_leaf': randint(1, 5),
            'max_features': ['auto', 'sqrt', 'log2']}

rf = RandomForestRegressor()

rand_search = RandomizedSearchCV(rf, param_distributions = param_dist,n_iter=5, cv=5,verbose=1, n_jobs=-1)

rand_search.fit(x_train, y_train)
print("Best Hyperparameters:")
print(rand_search.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...
